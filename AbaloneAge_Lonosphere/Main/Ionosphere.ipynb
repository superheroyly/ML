# %% [markdown]
# ## 导入相关库

# %%
# Importing the basic libraries. 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import pandas_profiling as pdb
import os
plt.style.use('seaborn-darkgrid')

# %%
# Loading the data. 查看Dataset目录下的文件
print(os.listdir('../Dataset/'))
# Out:
# ['abalone.csv', 'ionosphere_data.csv']

# %% [markdown]
# ## 导入数据

# %%
# Loading the data. 
# we will check how good or bad the data is, that we already have. 
data = pd.read_csv('../Dataset/ionosphere_data.csv')

# %% [markdown]
# ## 数据探索

# %%
# checking the data.  数据形状大小
print(data.shape)
# Out:
# (351, 35)

# %%
# checking the sample data for data. 前20条数据
data.head(20)
# Out:
#     column_a  column_b  column_c  column_d  column_e  column_f  column_g  \
# 0       True     False   0.99539  -0.05889   0.85243   0.02306   0.83398
# 1       True     False   1.00000  -0.18829   0.93035  -0.36156  -0.10868
# 2       True     False   1.00000  -0.03365   1.00000   0.00485   1.00000
# 3       True     False   1.00000  -0.45161   1.00000   1.00000   0.71216
# 4       True     False   1.00000  -0.02401   0.94140   0.06531   0.92106
# 5       True     False   0.02337  -0.00592  -0.09924  -0.11949  -0.00763
# 6       True     False   0.97588  -0.10602   0.94601  -0.20800   0.92806
# 7      False     False   0.00000   0.00000   0.00000   0.00000   1.00000
# 8       True     False   0.96355  -0.07198   1.00000  -0.14333   1.00000
# 9       True     False  -0.01864  -0.08459   0.00000   0.00000   0.00000
# 10      True     False   1.00000   0.06655   1.00000  -0.18388   1.00000
# 11      True     False   1.00000  -0.54210   1.00000  -1.00000   1.00000
# ...

# %%
# checking basic statistics of data.  统计数据
data.describe()
# Out:
#          column_c    column_d    column_e    column_f    column_g    column_h  \
# count  351.000000  351.000000  351.000000  351.000000  351.000000  351.000000
# mean     0.641342    0.044372    0.601068    0.115889    0.550095    0.119360
# std      0.497708    0.441435    0.519862    0.460810    0.492654    0.520750
# min     -1.000000   -1.000000   -1.000000   -1.000000   -1.000000   -1.000000
# 25%      0.472135   -0.064735    0.412660   -0.024795    0.211310   -0.054840
# 50%      0.871110    0.016310    0.809200    0.022800    0.728730    0.014710
# 75%      1.000000    0.194185    1.000000    0.334655    0.969240    0.445675
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#          column_i    column_j    column_k    column_l  ...    column_y  \
# count  351.000000  351.000000  351.000000  351.000000  ...  351.000000
# mean     0.511848    0.181345    0.476183    0.155040  ...    0.396135
# ...

# %%
# Checking the information about the data. 查看非缺失值总数
# this will tell us how many and what type of columns/rows we have in the data. 
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 351 entries, 0 to 350
# Data columns (total 35 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   column_a   351 non-null    bool
#  1   column_b   351 non-null    bool
#  2   column_c   351 non-null    float64
#  3   column_d   351 non-null    float64
#  4   column_e   351 non-null    float64
#  5   column_f   351 non-null    float64
#  6   column_g   351 non-null    float64
#  7   column_h   351 non-null    float64
#  8   column_i   351 non-null    float64
#  9   column_j   351 non-null    float64
#  10  column_k   351 non-null    float64
#  11  column_l   351 non-null    float64
#  12  column_m   351 non-null    float64
#  13  column_n   351 non-null    float64
#  14  column_o   351 non-null    float64
#  15  column_p   351 non-null    float64
#  16  column_q   351 non-null    float64
#  17  column_r   351 non-null    float64
#  18  column_s   351 non-null    float64
# ...

# %%
# 为了在生成数据集报告时不引入index索引，故将索引删去
d = data.reset_index(drop=True)

# %%
using pandas profiler once to look into all the data columns. 
data_profile = pdb.ProfileReport(d)
data_profile

# %%
df = data.copy()
df['column_ai'] = df['column_ai'].map({'g': 0, 'b': 1})   #　标签为ｇ改为０，反之为１

df.rename(columns={'column_ai': 'Class'}, inplace=True) # 修改特征名

# %%
# 标签不平衡
sns.countplot(x='Class', data=df)
plt.savefig("../img/Class_label.png", dpi=200)

num0, num1 = 0, 0
label = df['Class']
for i in label:
    if i == 0:
        num0 +=1
    else:
        num1 += 1
print("标签为0占比:{0}%, 标签为1占比:{1}%".format(round(num0/len(label), 2)*100, round(num1/len(label), 2)*100 ))
# Out:
# 标签为0占比:64.0%, 标签为1占比:36.0%

# %%
df['column_a'] = [1 if i == True else 0 for i in df['column_a']]
df['column_b'] = [1 if i == True else 0 for i in df['column_b']]
df.head()
# Out:
#    column_a  column_b  column_c  column_d  column_e  column_f  column_g  \
# 0         1         0   0.99539  -0.05889   0.85243   0.02306   0.83398
# 1         1         0   1.00000  -0.18829   0.93035  -0.36156  -0.10868
# 2         1         0   1.00000  -0.03365   1.00000   0.00485   1.00000
# 3         1         0   1.00000  -0.45161   1.00000   1.00000   0.71216
# 4         1         0   1.00000  -0.02401   0.94140   0.06531   0.92106
#
#    column_h  column_i  column_j  ...  column_z  column_aa  column_ab  \
# 0  -0.37708   1.00000   0.03760  ...  -0.51171    0.41078   -0.46168
# 1  -0.93597   1.00000  -0.04549  ...  -0.26569   -0.20468   -0.18401
# 2  -0.12062   0.88965   0.01198  ...  -0.40220    0.58984   -0.22145
# 3  -1.00000   0.00000   0.00000  ...   0.90695    0.51613    1.00000
# 4  -0.23255   0.77152  -0.16399  ...  -0.65158    0.13290   -0.53206
#
#    column_ac  column_ad  column_ae  column_af  column_ag  column_ah  Class
# ...

# %%
label = df['Class']
data = df.drop(columns='Class', axis=1)
print(type(data))
print("label.shape:",label.shape, "\ndata.shape:", data.shape)
# print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# label.shape: (351,)
# data.shape: (351, 34)

# %% [markdown]
# ## 数据归一化处理

# %%
from sklearn.preprocessing import MinMaxScaler   #引入sklkearn中的归一化模块

# 实例化一个转换器类
transfer=MinMaxScaler()   #rang范围可改变
# 调用transform转换
data = transfer.fit_transform(data)
# data.head()

# %% [markdown]
# ## 可视化高维数据(TSNE, PCA)

# %%
from sklearn.manifold import TSNE

x_embedded = TSNE(n_components=2).fit_transform(data)
plt.scatter(x_embedded[:, 0], x_embedded[:, 1], color=['green' if i else 'red' for i in label])
plt.savefig("../img/lonosphere_tsne.png", dpi=200)
plt.show()

# %%
from sklearn.decomposition import PCA

x_embedded = PCA(n_components=2).fit_transform(data)
plt.scatter(x_embedded[:, 0], x_embedded[:, 1], color=['green' if i else 'red' for i in label])
plt.savefig("../img/lonosphere_pca.png", dpi=200)
plt.show()

# %% [markdown]
# ## 选择最佳维度

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold


best_score, best_i, model_name = 0, 0, "None"
for i in range(1, 34):
    x_embedded = PCA(n_components=i).fit_transform(data)
#     plt.scatter(x_embedded[:, 0], x_embedded[:, 1], color=['green' if label else 'red' for label in y_train])
    X = x_embedded
    Y = label
    logreg = LogisticRegression()
    stratifiedkf = StratifiedKFold(n_splits=5)
    score = cross_val_score(logreg,X,Y,cv=stratifiedkf)
#     print("Cross Validation Scores are {}".format(score))
#     print("Average Cross Validation score :{}".format(score.mean()))
#     print('-'*10)
    
    if score.mean() > best_score:
        best_score, best_i, model_name = score.mean(), i, "LogisticRegression"
    
    estimator = KNeighborsClassifier()
    stratifiedkf = StratifiedKFold(n_splits=5)
    score = cross_val_score(estimator, X, Y, cv=stratifiedkf)
#     print("Cross Validation Scores are {}".format(score))
#     print("Average Cross Validation score :{}".format(score.mean()))
    if score.mean() > best_score:
        best_score, best_i, model_name = score.mean(), i, "KNeighborsClassifier"
#     print('*'*15)

    
print("Best_score={0}\nBest_dim={1}\nBest_model_name={2}".format(best_score, best_i, model_name))
# Out:
# Best_score=0.8917102615694166
# Best_dim=5
# Best_model_name=KNeighborsClassifier

# %%
# 根据训练集：测试集 = 4：1划分数据 分层抽样
from sklearn.model_selection import train_test_split
import random 
from sklearn.datasets import load_iris
from sklearn.model_selection import cross_val_score,StratifiedKFold
from sklearn.linear_model import LogisticRegression


X = PCA(n_components=5).fit_transform(data)
Y = label
logreg = LogisticRegression()
stratifiedkf = StratifiedKFold(n_splits=5)
score = cross_val_score(logreg,X,Y,cv=stratifiedkf)
print("Cross Validation Scores are {}".format(score))
print("Average Cross Validation score :{}".format(score.mean()))
# Out:
# Cross Validation Scores are [0.85915493 0.75714286 0.9        0.92857143 0.9       ]
# Average Cross Validation score :0.8689738430583501

# %% [markdown]
# ## 模型训练

# %%
estimator = KNeighborsClassifier()
stratifiedkf = StratifiedKFold(n_splits=5)
score = cross_val_score(estimator, X, Y, cv=stratifiedkf)
# print("Cross Validation Scores are {}".format(score))
# print("Average Cross Validation score :{}".format(score.mean())) # 

score4 = cross_val_score(estimator, X, Y, scoring='accuracy', cv=stratifiedkf)
print("Accuracy:", score4.mean())

score1 = cross_val_score(estimator, X, Y, scoring='f1_macro', cv=stratifiedkf)
print("F1-score:",score1.mean())

score2 = cross_val_score(estimator, X, Y, scoring='precision_macro', cv=stratifiedkf)
print("Precision:", score2.mean())

score3 = cross_val_score(estimator, X, Y, scoring='recall_macro', cv=stratifiedkf)
print("Recall:", score3.mean())

score5 = cross_val_score(estimator, X, Y, scoring='roc_auc', cv=stratifiedkf)
print("roc_auc:", score5.mean())
# Out:
# Accuracy: 0.8917102615694166
# F1-score: 0.8744185691218551
# Precision: 0.9072894638717621
# Recall: 0.8597435897435897
# roc_auc: 0.9187589743589744

# %%
logreg = LogisticRegression()
stratifiedkf = StratifiedKFold(n_splits=5)
score = cross_val_score(logreg, X, Y, cv=stratifiedkf)
# print("Cross Validation Scores are {}".format(score))
# print("Average Cross Validation score :{}".format(score.mean())) # 

score4 = cross_val_score(logreg, X, Y, scoring='accuracy', cv=stratifiedkf)
print("Accuracy:", score4.mean())

score1 = cross_val_score(logreg, X, Y, scoring='f1_macro', cv=stratifiedkf)
print("F1-score:",score1.mean())

score2 = cross_val_score(logreg, X, Y, scoring='precision_macro', cv=stratifiedkf)
print("Precision:", score2.mean())

score3 = cross_val_score(logreg, X, Y, scoring='recall_macro', cv=stratifiedkf)
print("Recall:", score3.mean())

score5 = cross_val_score(logreg, X, Y, scoring='roc_auc', cv=stratifiedkf)
print("roc_auc:", score5.mean())
# Out:
# Accuracy: 0.8689738430583501
# F1-score: 0.8460088040410799
# Precision: 0.8838890352803397
# Recall: 0.8317606837606839
# roc_auc: 0.9000752136752137

# %% [markdown]
# ## 调参

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC

tuned_parameters = [
    {"kernel": ["rbf"], "gamma": [1e-3, 1e-4], "C": [1, 10, 100, 1000]},
    {"kernel": ["linear"], "C": [1, 10, 100, 1000]},
]

grid_search = GridSearchCV(
    SVC(), tuned_parameters, scoring="accuracy"
)
grid_search.fit(X, Y)
# Out:
# GridSearchCV(estimator=SVC(),
#              param_grid=[{'C': [1, 10, 100, 1000], 'gamma': [0.001, 0.0001],
#                           'kernel': ['rbf']},
#                          {'C': [1, 10, 100, 1000], 'kernel': ['linear']}],
#              scoring='accuracy')

# %%
grid_search.best_params_
# Out:
# {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}

# %%
from sklearn.svm import SVC

clf = SVC(kernel='rbf', C=1000, gamma=0.001, random_state=42)
stratifiedkf = StratifiedKFold(n_splits=5)

score4 = cross_val_score(clf, X, Y, scoring='accuracy', cv=stratifiedkf)
print("Accuracy:", score4.mean())

score1 = cross_val_score(clf, X, Y, scoring='f1_macro', cv=stratifiedkf)
print("F1-score:",score1.mean())

score2 = cross_val_score(clf, X, Y, scoring='precision_macro', cv=stratifiedkf)
print("Precision:", score2.mean())

score3 = cross_val_score(clf, X, Y, scoring='recall_macro', cv=stratifiedkf)
print("Recall:", score3.mean())

score5 = cross_val_score(clf, X, Y, scoring='roc_auc', cv=stratifiedkf)
print("roc_auc:", score5.mean())
# Out:
# Accuracy: 0.8861167002012073
# F1-score: 0.8684058980279676
# Precision: 0.8988344747787472
# Recall: 0.8557606837606837
# roc_auc: 0.906871794871795

# %%
from sklearn import tree

dt = tree.DecisionTreeClassifier()
score4 = cross_val_score(dt, X, Y, scoring='accuracy', cv=stratifiedkf)
print("Accuracy:", score4.mean())

score1 = cross_val_score(dt, X, Y, scoring='f1_macro', cv=stratifiedkf)
print("F1-score:",score1.mean())

score2 = cross_val_score(dt, X, Y, scoring='precision_macro', cv=stratifiedkf)
print("Precision:", score2.mean())

score3 = cross_val_score(dt, X, Y, scoring='recall_macro', cv=stratifiedkf)
print("Recall:", score3.mean())

score5 = cross_val_score(dt, X, Y, scoring='roc_auc', cv=stratifiedkf)
print("roc_auc:", score5.mean())
# Out:
# Accuracy: 0.871830985915493
# F1-score: 0.8511603144663293
# Precision: 0.8550081092542422
# Recall: 0.8455042735042735
# roc_auc: 0.8557264957264958

# %%
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import confusion_matrix

y_train_pred = cross_val_predict(estimator, X, Y, cv=5)
confusion_matrix(Y, y_train_pred)
# Out:
# array([[219,   6],
#        [ 32,  94]], dtype=int64)

# %%
import scikitplot as skplt
# 混淆矩阵
plot = skplt.metrics.plot_confusion_matrix(Y, y_train_pred)
plt.rcParams['font.sans-serif'] = ['SimHei']  # 用来正常显示中文标签
plt.xlabel('True')
plt.ylabel('Prediction')
plt.title('')
plt.savefig("../img/lonosphere_confusion_matrix.png", dpi=200)
plt.show()

# %%
import matplotlib.pyplot as plt

from sklearn import svm
from sklearn.metrics import auc
from sklearn.metrics import RocCurveDisplay
from sklearn.model_selection import StratifiedKFold

# Run classifier with cross-validation and plot ROC curves
cv = StratifiedKFold(n_splits=5)
classifier = KNeighborsClassifier()
# classifier = svm.SVC(kernel="linear", probability=True, random_state=42)

tprs = []
aucs = []
mean_fpr = np.linspace(0, 1, 100)
y = Y
fig, ax = plt.subplots()
for i, (train, test) in enumerate(cv.split(X, y)):
    classifier.fit(X[train], y[train])
    viz = RocCurveDisplay.from_estimator(
        classifier,
        X[test],
        y[test],
        name="ROC fold {}".format(i),
        alpha=0.3,
        lw=1,
        ax=ax,
    )
    interp_tpr = np.interp(mean_fpr, viz.fpr, viz.tpr)
    interp_tpr[0] = 0.0
    tprs.append(interp_tpr)
    aucs.append(viz.roc_auc)

ax.plot([0, 1], [0, 1], linestyle="--", lw=2, color="r", label="Chance", alpha=0.8)

mean_tpr = np.mean(tprs, axis=0)
mean_tpr[-1] = 1.0
mean_auc = auc(mean_fpr, mean_tpr)
std_auc = np.std(aucs)
ax.plot(
    mean_fpr,
    mean_tpr,
    color="b",
    label=r"Mean ROC (AUC = %0.2f $\pm$ %0.2f)" % (mean_auc, std_auc),
    lw=2,
    alpha=0.8,
)

std_tpr = np.std(tprs, axis=0)
tprs_upper = np.minimum(mean_tpr + std_tpr, 1)
tprs_lower = np.maximum(mean_tpr - std_tpr, 0)
ax.fill_between(
    mean_fpr,
    tprs_lower,
    tprs_upper,
    color="grey",
    alpha=0.2,
    label=r"$\pm$ 1 std. dev.",
)

ax.set(
    xlim=[-0.05, 1.05],
    ylim=[-0.05, 1.05],
    title="Lonosphere Classify Result",
)
ax.legend(loc="lower right")
plt.savefig("../img/lonosphere_ROC.png", dpi=200)
plt.show()
